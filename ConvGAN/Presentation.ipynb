# %%
import pickle
import numpy as np
from matplotlib import pyplot as plt
import glob

FONTSIZE=18

plt.rcParams['figure.figsize']=(10,10)
plt.rcParams['font.size']=FONTSIZE

# %%
image=np.zeros((24,24))
#C chord
image[3,0:7]=1
image[7,0:7]=1
image[10,0:7]=1
#F chord
image[8,8:15]=1
image[12,8:15]=1
image[15,8:15]=1
#G chord
image[10,16:]=1
image[14,16:]=1
image[17,16:]=1
fig, ax = plt.subplots(1,1)
ax.imshow(image,cmap='Purples',origin='lower')
ax.set_yticks(np.arange(24))
y_label_list=['A','A#','B','C','C#','D','D#','E','F','F#','G','G#','A','A#','B','C','C#','D','D#','E','F','F#','G','G#']
ax.set_yticklabels(y_label_list)
ax.set_xticks([])
ax.set_xticklabels([])
plt.title('Linear Mapping')
plt.savefig('./presentation/linear_mapping.png',bbox_inches='tight')

# %%
image=np.zeros((12,12))
#C chord
image[3,0:3]=1
image[7,0:3]=1
image[10,0:3]=1
#F chord
image[8,4:7]=1
image[0,4:7]=1
image[3,4:7]=1
#G chord
image[10,8:11]=1
image[2,8:11]=1
image[5,8:11]=1
fig, ax = plt.subplots(1,1)
ax.imshow(image,cmap='Purples',origin='lower')
ax.set_yticks(np.arange(12))
y_label_list=['A','A#','B','C','C#','D','D#','E','F','F#','G','G#']
ax.set_yticklabels(y_label_list)
ax.set_xticks([])
ax.set_xticklabels([])
plt.title('Linear Mapping')
plt.savefig('./presentation/linear_mapping_small.png',bbox_inches='tight')

# %%
y_label_list=['A','E','B','F#','C#','G#','D#','A#','F','C','G','D','A','E','B','F#','C#','G#','D#','A#','F','C','G','D']

image=np.zeros((24,24))
#C chord
image[9,0:7]=1
image[1,0:7]=1
image[10,0:7]=1
#F chord
image[8,8:15]=1
image[12,8:15]=1
image[21,8:15]=1
#G chord
image[10,16:]=1
image[14,16:]=1
image[23,16:]=1
fig, ax = plt.subplots(1,1)
ax.imshow(image,cmap='Purples',origin='lower')
ax.set_yticks(np.arange(24))
ax.set_yticklabels(y_label_list)
ax.set_xticks([])
ax.set_xticklabels([])
plt.title('Minor Fifths Mapping')
plt.savefig('./presentation/fifths_mapping.png',bbox_inches='tight')

# %%
y_label_list=['A','E','B','F#','C#','G#','D#','A#','F','C','G','D']

image=np.zeros((12,12))
#C chord
image[9,0:3]=1
image[1,0:3]=1
image[10,0:3]=1
#F chord
image[8,4:7]=1
image[0,4:7]=1
image[9,4:7]=1
#G chord
image[10,8:11]=1
image[2,8:11]=1
image[9,8:11]=1
fig, ax = plt.subplots(1,1)
ax.imshow(image,cmap='Purples',origin='lower')
ax.set_yticks(np.arange(12))
ax.set_yticklabels(y_label_list)
ax.set_xticks([])
ax.set_xticklabels([])
plt.title('Minor Fifths Mapping')
plt.savefig('./presentation/fifths_mapping_small.png',bbox_inches='tight')

# %%
y_label_list=['D#','A#','F','C','G','D','A','E','B','F#','C#','G#']

image=np.zeros((12,12))
#C chord
image[3,0:3]=1
image[4,0:3]=1
image[7,0:3]=1
#F chord
image[2,4:7]=1
image[3,4:7]=1
image[6,4:7]=1
#G chord
image[3,8:11]=1
image[4,8:11]=1
image[7,8:11]=1
fig, ax = plt.subplots(1,1)
ax.imshow(image,cmap='Purples',origin='lower')
ax.set_yticks(np.arange(12))
ax.set_yticklabels(y_label_list)
ax.set_xticks([])
ax.set_xticklabels([])
plt.title('Minor Fifths Mapping')
plt.savefig('./presentation/fifths_mapping_small2.png',bbox_inches='tight')
