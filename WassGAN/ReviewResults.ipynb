# %%
import pickle
import numpy as np
from matplotlib import pyplot as plt
import glob

FONTSIZE=18

plt.rcParams['figure.figsize']=(15,8)
plt.rcParams['font.size']=FONTSIZE

# %%
fp=open('./results_boost5_clip0.01/WassGan_fifths_Gfilters_48_48_48_Cfilters_64_64_Gstrides_12-2_2-4_Cstrides_2_2_results_e750.pkl','rb')
#formerly results1/
#in oscer just results/
results=pickle.load(fp)
fp.close()

# %%
print(results.keys())
# Out:
# dict_keys(['critic_summary', 'generator_summary', 'args', 'fbase', 'critic_real_loss', 'critic_fake_loss', 'generator_loss'])

# %%
critic_boost=5

gen_loss=results['generator_loss']
critic_real_loss=results['critic_real_loss']
critic_fake_loss=results['critic_fake_loss']

batches=np.arange(len(gen_loss))
batches_critic=np.arange(len(critic_real_loss))/critic_boost
plt.plot(batches,gen_loss,label='Generator')
plt.plot(batches_critic,critic_real_loss,label='Critic Real')
plt.plot(batches_critic,critic_fake_loss,label='Critic Fake')
plt.xlabel('Time (or Batches for Generator)')
plt.ylabel('Loss')
plt.legend(loc='best')

# %% [markdown]
# # The critic seems to be losing pretty handily to the generator on fake images
#
# - next run will have critic_boost=10

# %%
fp=open('./results_boost10_clip0.01/WassGan_fifths_Gfilters_48_48_48_Cfilters_64_64_Gstrides_12-2_2-4_Cstrides_2_2_Cboost_10_results_e375.pkl','rb')
#formerly results2/
#in oscer also results2/
results=pickle.load(fp)
fp.close()

# %%
critic_boost=10

gen_loss=results['generator_loss']
critic_real_loss=results['critic_real_loss']
critic_fake_loss=results['critic_fake_loss']

batches=np.arange(len(gen_loss))
batches_critic=np.arange(len(critic_real_loss))/critic_boost
plt.plot(batches,gen_loss,label='Generator')
plt.plot(batches_critic,critic_real_loss,label='Critic Real')
plt.plot(batches_critic,critic_fake_loss,label='Critic Fake')
plt.xlabel('Time (or Batches for Generator)')
plt.ylabel('Loss')
plt.legend(loc='best')

# %% [markdown]
# # Still not sufficient, though it did something interesting around 5000 batches
#
# # Let's try different weight clipping values
#
# - we've already done 0.01
#
#
# # here's boost 10 clip 0.001

# %% [markdown]
# # here's boost 10 clip 0.1

# %% [markdown]
# # Let's also try critic_boost=15 with weight_clip=0.01
